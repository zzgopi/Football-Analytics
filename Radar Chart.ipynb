# %%
import pandas as pd
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar

# %%
df =pd.read_csv(r'C:\Users\SG\Downloads\radars.csv')

# %%
df
# Out:
#       Rk                                   Player   Nation   Pos  \
# 0      1  Patrick van Aanholt\Patrick-van-Aanholt   nl NED    DF
# 1      2              Tammy Abraham\Tammy-Abraham  eng ENG    FW
# 2      3                      Che Adams\Che-Adams  eng ENG    FW
# 3      4        Tosin Adarabioyo\Tosin-Adarabioyo  eng ENG    DF
# 4      5                            Adrián\Adrian   es ESP    GK
# ..   ...                                      ...      ...   ...
# 500  501                  Andi Zeqiri\Andi-Zeqiri   ch SUI  FWDF
# 501  502  Oleksandr Zinchenko\Oleksandr-Zinchenko   ua UKR    DF
# 502  503                Hakim Ziyech\Hakim-Ziyech   ma MAR  FWMF
# 503  504                    Kurt Zouma\Kurt-Zouma   fr FRA    DF
# 504  505          Martin Ødegaard\Martin-Odegaard   no NOR    MF
#
#                Squad     Age  Born   90s  Gls  Sh  ...  Dist  FK  PK  PKatt  \
# 0     Crystal Palace  30-185  1990  13.7    0  15  ...  20.6   3   0      0
# ...

# %%
df['Player']=df['Player'].str.split('\\',expand=True)[0]

# %%
df=df['Player',]
# Out:
#       Rk               Player   Nation   Pos            Squad     Age  Born  \
# 0      1  Patrick van Aanholt   nl NED    DF   Crystal Palace  30-185  1990
# 1      2        Tammy Abraham  eng ENG    FW          Chelsea  23-151  1997
# 2      3            Che Adams  eng ENG    FW      Southampton  24-232  1996
# 3      4     Tosin Adarabioyo  eng ENG    DF           Fulham  23-159  1997
# 4      5               Adrián   es ESP    GK        Liverpool  34-058  1987
# ..   ...                  ...      ...   ...              ...     ...   ...
# 500  501          Andi Zeqiri   ch SUI  FWDF         Brighton  21-253  1999
# 501  502  Oleksandr Zinchenko   ua UKR    DF  Manchester City  24-077  1996
# 502  503         Hakim Ziyech   ma MAR  FWMF          Chelsea  27-348  1993
# 503  504           Kurt Zouma   fr FRA    DF          Chelsea  26-126  1994
# 504  505      Martin Ødegaard   no NOR    MF          Arsenal  22-075  1998
#
# ...

# %%
df=df[(df['Player']=='Tammy Abraham')|(df['Player']=='Timo Werner') ].reset_index()

# %%
df
# Out:
#    index   Rk         Player   Nation Pos    Squad     Age  Born   90s  Gls  \
# 0      1    2  Tammy Abraham  eng ENG  FW  Chelsea  23-151  1997  11.3    6
# 1    481  482    Timo Werner   de GER  FW  Chelsea  24-361  1996  20.5    5
#
#    ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  Matches
# 0  ...   9.9   0   0      0  5.6   5.6     0.18   0.4      0.4  Matches
# 1  ...  13.7   0   0      0  8.4   8.4     0.15  -3.4     -3.4  Matches
#
# [2 rows x 27 columns]

# %%
df=df.drop(['index','Rk','Nation','Pos','Squad','Age','Born','90s','FK','PK','PKatt','Matches'],axis=1)

# %%
df
# Out:
#           Player  Gls  Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  Dist   xG  \
# 0  Tammy Abraham    6  31   13  41.9   2.73    1.15  0.19   0.46   9.9  5.6
# 1    Timo Werner    5  55   21  38.2   2.69    1.03  0.09   0.24  13.7  8.4
#
#    npxG  npxG/Sh  G-xG  np:G-xG
# 0   5.6     0.18   0.4      0.4
# 1   8.4     0.15  -3.4     -3.4

# %%
params= list(df.columns)
params= params[1:]

# %%
params
# Out:
# ['Gls',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'xG',
#  'npxG',
#  'npxG/Sh',
#  'G-xG',
#  'np:G-xG']

# %%
ranges=[]
a_values =[]
b_values =[]

for x in params:
    a=min(df[x])
    a=a-(a*.25)
    
    b=max(df[x])
    b=b+(b*.25)
    
    ranges.append((a,b))
    
a_values= df.iloc[0].values.tolist()
b_values= df.iloc[1].values.tolist()

# %%
a_values=a_values[1:]
b_values=b_values[1:]

# %%
values= [a_values,b_values]
values
# Out:
# [[6, 31, 13, 41.9, 2.73, 1.15, 0.19, 0.46, 9.9, 5.6, 5.6, 0.18, 0.4, 0.4],
#  [5, 55, 21, 38.2, 2.69, 1.03, 0.09, 0.24, 13.7, 8.4, 8.4, 0.15, -3.4, -3.4]]

# %%
ranges
# Out:
# [(3.75, 7.5),
#  (23.25, 68.75),
#  (9.75, 26.25),
#  (28.650000000000002, 52.375),
#  (2.0175, 3.4125),
#  (0.7725, 1.4375),
#  (0.0675, 0.2375),
#  (0.18, 0.5750000000000001),
#  (7.425000000000001, 17.125),
#  (4.199999999999999, 10.5),
#  (4.199999999999999, 10.5),
#  (0.11249999999999999, 0.22499999999999998),
#  (-2.55, 0.5),
#  (-2.55, 0.5)]

# %%
title = dict(
    title_name = 'Tammy Abraham',
    title_color ='red',
    subtitle_name= 'Chelsea',
    subtitle_color= 'red',
    title_name_2 = 'Tammy Abraham',
    title_color_2 ='blue',
    subtitle_name_2 = 'Chelsea',
    subtitle_color_2 = 'blue',
    title_fontsize= 15,
    sbutitle_fontsize=15
)

endnote ='test  from FBREF'

# %%
radar= Radar()

fig, ax = radar.plot_radar(ranges= ranges, params=params,values=values,
                           radar_color=['red','blue'],alpha=[.75,.6],title=title,
                           endnote=endnote,compare=True)
